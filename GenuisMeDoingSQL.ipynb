# %%
import pandas as pd
import psycopg2

# %% [markdown]
# # from SQL to CSV

# %%
try:
    connection = psycopg2.connect(user="postgres",
                                  password="anon",
                                  host="localhost",
                                  database="postgres")
    cursor = connection.cursor()
    postgreSQL_select_Query = """
    select * from "FactBilling"
    """

    cursor.execute(postgreSQL_select_Query)
    
    records = cursor.fetchall()

except (Exception, psycopg2.Error) as error:
    print("Error while fetching data from PostgreSQL", error)

finally:
    # closing database connection.
    if connection:
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# PostgreSQL connection is closed

# %%
df = pd.DataFrame(records, columns=['bill_id', 'customer_id', 'month_id', 'billed_amount'])
df
# Out:
#         bill_id  customer_id  month_id  billed_amount
# 0             1            1     20091           5060
# 1             2          614     20091           9638
# 2             3          615     20091          11573
# 3             4          616     20091          18697
# 4             5          617     20091            944
# ...         ...          ...       ...            ...
# 131995   131996          378     20199           3725
# 131996   131997          379     20199          13198
# 131997   131998          380     20199           5509
# 131998   131999          978     20199          12103
# 131999   132000          466     20199           5567
#
# [132000 rows x 4 columns]

# %%
df.to_csv('DELTE_ME.csv', index=False)

# %%
df = pd.read_csv('DELTE_ME.csv')
df
# Out:
#         bill_id  customer_id  month_id  billed_amount
# 0             1            1     20091           5060
# 1             2          614     20091           9638
# 2             3          615     20091          11573
# 3             4          616     20091          18697
# 4             5          617     20091            944
# ...         ...          ...       ...            ...
# 131995   131996          378     20199           3725
# 131996   131997          379     20199          13198
# 131997   131998          380     20199           5509
# 131998   131999          978     20199          12103
# 131999   132000          466     20199           5567
#
# [132000 rows x 4 columns]

# %% [markdown]
# # from csv to sql
# from sqlalchemy import create_engine
#
# engine = create_engine('postgresql://username:password@localhost:5432/mydatabase')
#
# df.to_sql('table_name', engine)

# %% [markdown]
# # Extract

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:anon@localhost:5432/postgres')
df.to_sql('testtable4', engine)
# Out:
# 1000

# %%
df = pd.read_csv('C:/Users/MANAL/Random datasets/dataset_olympics.csv')
df
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ...

# %% [markdown]
# # Loading

# %%
df.to_sql('Abu Saa', engine)
# Out:
# 1000
